# %% [markdown]
# <a href="https://colab.research.google.com/github/Cosider24/1-md-21_Torkhov_Vladislav/blob/main/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%D0%B0_Superstore_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Анализ продаж Superstore
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Superstore_Sales_train.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df = df.drop(['Row ID'],axis=1)

# %%
df.shape
# Out:
# (9800, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   object
#  1   Order Date     9800 non-null   object
#  2   Ship Date      9800 non-null   object
#  3   Ship Mode      9800 non-null   object
#  4   Customer ID    9800 non-null   object
#  5   Customer Name  9800 non-null   object
#  6   Segment        9800 non-null   object
#  7   Country        9800 non-null   object
#  8   City           9800 non-null   object
#  9   State          9800 non-null   object
#  10  Postal Code    9789 non-null   float64
#  11  Region         9800 non-null   object
#  12  Product ID     9800 non-null   object
#  13  Category       9800 non-null   object
#  14  Sub-Category   9800 non-null   object
#  15  Product Name   9800 non-null   object
#  16  Sales          9800 non-null   float64
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst = True)

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   object
#  1   Order Date     9800 non-null   datetime64[ns]
#  2   Ship Date      9800 non-null   datetime64[ns]
#  3   Ship Mode      9800 non-null   object
#  4   Customer ID    9800 non-null   object
#  5   Customer Name  9800 non-null   object
#  6   Segment        9800 non-null   object
#  7   Country        9800 non-null   object
#  8   City           9800 non-null   object
#  9   State          9800 non-null   object
#  10  Postal Code    9789 non-null   float64
#  11  Region         9800 non-null   object
#  12  Product ID     9800 non-null   object
#  13  Category       9800 non-null   object
#  14  Sub-Category   9800 non-null   object
#  15  Product Name   9800 non-null   object
#  16  Sales          9800 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
category_sales = df.groupby('Category')['Sales'].sum()
print(f'Категория "{category.idxmax()}" приносит больше всего выручки, а именно: {category.max()}')
# Out:
# Категория "Technology" приносит больше всего выручки, а именно: 827455.873

# %%
category_sales.plot(kind='bar', color=['green', 'yellow', 'blue'])
plt.title('Общая выручка по категориям товаров')
plt.ylabel('Выручка')
plt.xlabel('Категория')
plt.show()

# %%
df['Month'] = df['Order Date'].dt.year
df.groupby('Month')['Sales'].sum()
# Out:
# Month
# 2015    479856.2081
# 2016    459436.0054
# 2017    600192.5500
# 2018    722052.0192
# Name: Sales, dtype: float64

# %%
annual_sales = df.groupby('Month')['Sales'].sum()
annual_sales.plot(kind='line', color=['blue'])
plt.title('Общая выручка по годам')
plt.ylabel('Выручка')
plt.xlabel('Год')
plt.xticks(range(2015, 2019))
plt.grid(True)
plt.show()

# %% [markdown]
# Самая прибыльная категория - Technology (827456).
#
# Самый прибыльный год - 2018 (722052).
